# %% [markdown]
# ## count_min 多核折线图

# %%
# %run cm_core_line.py

# %% [markdown]
# ## count_min 多流折线图

# %%
# %run cm_flow_line.py

# %% [markdown]
# ## nitro 多核折线图

# %%
# %run nitro_core_line.py

# %% [markdown]
# ## nitro 多流折线图

# %%
# %run nitro_flow_line.py

# %% [markdown]
# ## unimon 多核折线图

# %%
# %run unimon_core_line.py

# %% [markdown]
# ## unimon 多流折线图

# %%
# %run unimon_flow_line.py

# %% [markdown]
# ## 实现方式对比条状图

# %%
# %run total_bar.py

# %% [markdown]
# ## array 多核折线图

# %%
# %run array_cores_line.py

# %% [markdown]
# ## array 多读写比例折线图

# %%
# %run array_rw_line.py

# %% [markdown]
# ## lpm 多流折线图

# %%
# %run lpm_flow_line.py

# %% [markdown]
# ## lpm 多路由规则折线图

# %%
# %run lpm_rules_line.py

# %% [markdown]
# ## frame 框架性能损耗图

# %%
# %run frame_bar.py

# %% [markdown]
# ## op占比图

# %%
# %run op_partition_bar.py

# %% [markdown]
# ## motivation 占比图

# %%
# %run partition_bar.py

# %% [markdown]
# ## heap_cm对比条状图

# %%
# %run heap_cm_bar.py

# %% [markdown]
# ## challenge2(A)图

# %%
# %run challenge2A_line.py

# %% [markdown]
# ## challenge2(B)图

# %%
# %run challenge2B_line.py
